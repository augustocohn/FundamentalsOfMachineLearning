# %% [markdown]
# # Short Assignment 6
#
# **This is an individual assignment.**

# %% [markdown]
# # Question 1
#
# Consider the following perceptron:

# %%
from IPython.display import Image
Image('figures/Perceptron.png', width=400)

# %% [markdown]
# Recall that the perceptron uses the activation function:
#
# \begin{align*}
# \phi(x)=\begin{cases}-1 & x\leq 0 \\ 1 & x>0\end{cases}
# \end{align*}
#
# And the cost function is:
#
# \begin{align*}
# E_p(\mathbf{w},b) = -\sum_{m\in\mathcal{M}}(\mathbf{w}^T\mathbf{x}_n + b)^T t_n
# \end{align*}
#
# where  is the set of all misclassified points. The update equations for the weights and bias term are:
#
# \begin{align*}
# \mathbf{w}^{(t+1)} \longleftarrow & \mathbf{w}^{(t)} - \eta \frac{\partial E_p(\mathbf{w},b)}{\partial \mathbf{w}} = \mathbf{w}^{(t)} + \eta \mathbf{x}_n t_n\\
# b^{(t+1)} \longleftarrow & b^{(t)} - \eta\frac{\partial E_p(\mathbf{w},b)}{\partial b} = b^{(t)} + \eta t_n
# \end{align*}
#
# Suppose you have the following 5 data samples $(x,y)$ and their corresponding labels $t$:
#
# \begin{align*}
# (x_1,y_1)=(1,0)\text{ with }t_1&=1\\
# (x_2,y_2)=(4,2)\text{ with }t_2&=1\\
# (x_3,y_3)=(0,-1)\text{ with }t_3&=-1\\
# (x_4,y_4)=(-1,-1)\text{ with }t_4&=-1\\
# (x_5,y_5)=(-2,1)\text{ with }t_5&=-1
# \end{align*}
#
# What is the **smallest** value for the learning rate $\eta$ such that the updated network will result in zero misclassified points using **only one iteration**?

# %%
Image('figures/SA6-1.png', width=400)

# %%
Image('figures/SA6-2.png', width=400)

# %% [markdown]
# # Question 2
#
# In this problem, you will be characterizing the Lagrangian function for optimization problems with inequality constraints.
#
# ## Case 1
# Consider the following optimization problem:
# \begin{align*}
# &\arg_{x_1, x_2} \min x_1 + x_2 \\
# &\text{ subject to } x_1^2 + x_2^2 \geq 2
# \end{align*}
#
# 1. Write down the Lagrangian function for this optimization problem.
#
# 2. What are the Karush-Kuhn-Tucker (KKT) conditions for this Lagrangian function?
#
# ## Case 2
# Consider the following optimization problem:
# \begin{align*}
# &\arg_{x_1, x_2} \min x_1 + x_2 \\
# &\text{ subject to } x_1^2 + x_2^2 \leq 2
# \end{align*}
#
# 1. Write down the Lagrangian function for this optimization problem.
#
# 2. What are the Karush-Kuhn-Tucker (KKT) conditions for this Lagrangian function?
#
# ## Case 3
# Consider the following optimization problem:
# \begin{align*}
# &\arg_{x_1, x_2} \max x_1 + x_2 \\
# &\text{ subject to } x_1^2 + x_2^2 \leq 2
# \end{align*}
#
# 1. Write down the Lagrangian function for this optimization problem.
#
# 2. What are the Karush-Kuhn-Tucker (KKT) conditions for this Lagrangian function?

# %%
Image('figures/SA6-3.png', width=400)

# %% [markdown]
# # Question 3
#
# Suppose you have the following training data set and suppose you expect your training data set to be representative of your test data. Of all of the methods we can covered in the course, which would you use to classify this data into black x vs. red o. Why? Justify your answer.

# %%
Image('figures/Cross_circles.png', width=400)

# %% [markdown]
# I would use kNN w/ k={2,3} to classify this dataset although I do believe that we could generate an multilayered perceptron that would be able to produce an outcome with similar accuracy. On thing that stands out to me is the the classes look like they can be seperated with strips that alternate diagonally meaning that we could in theory find lines that will best linearly seperate the 2 classes which is why I believe LDA could be a relatively safe choice for a classifier. I chose kNN w/ k={2,3} because I believe a complex decision boundary will be needed to classify data points with the highest accuracy. Some of the clumps are not linearly seperable and kNN with a small k should have no problem generating decision boundaries to best fit the training data and allow for decent generalizability in the test set.

# %% [markdown]
# # Question 4
#
# Consider the following performance from four different classifiers, A, B, C and D on three data sets. The classifiers used to produce these results are: Fisher's Linear Discriminant, k-NN with k=3, Naïve Bayes classifier, and SVM with RBF kernel.
#
# Which classifier corresponds to which performance? Clearly justify your reasoning.

# %%
Image('figures/Classifiers.png', width=800)

# %% [markdown]
# - Classifier A = Naive Bayes
#     - A non-linear decision boundary that is good at classifying circular/linearly seperable classes but, is poor at most other shapes
# - Classifier B = LDA
#     - Completely linear decision bounadry that is poor at classifying any dataset that is not linearly seperable
# - Classifier C = SVM w/ RBF Kernel
#     - A non-linear decision boundary utilizing a soft margin. Creates smooth complex decision boundaries
# - Classifier D = kNN
#     - Very jagged decision boundary that is very recognizable as kNN. Good at classifying datasets of almost any shape but, struggles with inbalanced classes.

# %% [markdown]
# # Submit Your Solution
#
# Confirm that you've successfully completed the assignment.
#
# ```add``` and ```commit``` the final version of your work, and ```push``` your code to your GitHub repository.
#
# Submit the URL of your GitHub Repository as your assignment submission on Canvas.
